# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("full_dataset.csv")

# %%
df_main_dataset=df.copy()

# %%
df[" Label"].value_counts()
# Out:
#  Label
# BENIGN          1140491
# PortScan         158930
# DDoS             128027
# Bot                1966
# Infiltration         31
# Name: count, dtype: int64

# %%
def conversion(label):
    if label=="BENIGN":
        return "Normal"
    else: return "Attack"

# %%
df_main_dataset[" Label"]=df[" Label"].apply(conversion)

# %% [markdown]
# # What is done here
# > Here  we see we wanna split the data into two parts inn first data we have only normal and attack means binary classification
# > in second one we need to split the attck strategy and we need to split attack

# %%
df_attack=df[df[" Label"]!="BENIGN"]

# %%
# df_attack.to_csv("phase2.csv")
